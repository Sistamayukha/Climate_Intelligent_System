# %%
# !pip install pandas scikit-learn spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\sista\appdata\roaming\python\python314\site-packages (3.0.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: spacy in c:\users\sista\appdata\roaming\python\python314\site-packages (3.8.13)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\sista\appdata\roaming\python\python314\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sista\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\sista\appdata\roaming\python\python314\site-packages (from pandas) (2026.1)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from scikit-learn) (1.5.3)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (0.24.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (82.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sista\appdata\roaming\python\python314\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\sista\appdata\roaming\python\python314\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sista\appdata\roaming\python\python314\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sista\appdata\roaming\python\python314\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sista\appdata\roaming\python\python314\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sista\appdata\roaming\python\python314\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sista\appdata\roaming\python\python314\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in c:\users\sista\appdata\roaming\python\python314\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in c:\users\sista\appdata\roaming\python\python314\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.2.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\sista\appdata\roaming\python\python314\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in c:\users\sista\appdata\roaming\python\python314\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.0)
# Requirement already satisfied: httpx>=0.24.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in c:\users\sista\appdata\roaming\python\python314\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in c:\users\sista\appdata\roaming\python\python314\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\sista\appdata\roaming\python\python314\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: six>=1.5 in c:\users\sista\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sista\appdata\roaming\python\python314\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in c:\users\sista\appdata\roaming\python\python314\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sista\appdata\roaming\python\python314\site-packages (from jinja2->spacy) (3.0.3)
# Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.1 MB 9.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 12.5 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 14.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 13.3 MB/s  0:00:00
# Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl (37.3 MB)
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    --- ------------------------------------ 3.7/37.3 MB 17.0 MB/s eta 0:00:02
#    -------- ------------------------------- 7.6/37.3 MB 18.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 11.0/37.3 MB 17.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 15.2/37.3 MB 18.1 MB/s eta 0:00:02
#    ------------------- -------------------- 18.6/37.3 MB 17.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.0/37.3 MB 17.8 MB/s eta 0:00:01
#    --------------------------- ------------ 25.7/37.3 MB 17.9 MB/s eta 0:00:01
#    -------------------------------- ------- 29.9/37.3 MB 17.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 33.3/37.3 MB 17.9 MB/s eta 0:00:01
#    ---------------------------------------  37.2/37.3 MB 18.1 MB/s eta 0:00:01
#    ---------------------------------------  37.2/37.3 MB 18.1 MB/s eta 0:00:01
#    ---------------------------------------- 37.3/37.3 MB 15.5 MB/s  0:00:02
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, scikit-learn
#
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    ---------------------------------------- 3/3 [scikit-learn]
#
# Successfully installed scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import json

files = [
    r"D:\Climate_Intelligent_System\data\annotated\mayukha_annotations.json",
    r"D:\Climate_Intelligent_System\data\annotated\harshini_annotations.json",
    r"D:\Climate_Intelligent_System\data\annotated\ashley_annotations.json"
]

merged = []
for file in files:
    with open(file, "r", encoding="utf-8") as f:
        data = json.load(f)
        merged.extend(data)

with open(r"D:\Climate_Intelligent_System\data\processed\merged_annotations.json", "w", encoding="utf-8") as f:
    json.dump(merged, f, indent=2)

print(f"Total tasks merged: {len(merged)}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 11
#       7 ]
#       8
#       9 merged = []
#      10 for file in files:
# ---> 11     with open(file, "r", encoding="utf-8") as f:
#      12         data = json.load(f)
#      13         merged.extend(data)
#      14
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Climate_Intelligent_System\\data\\annotated\\harshini_annotations.json'
