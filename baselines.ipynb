# %%
import sys
print(f"Python version: {sys.version}")
print(f"Python path: {sys.executable}")
# Out:
# Python version: 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# Python path: C:\Users\Sista\AppData\Local\Programs\Python\Python311\python.exe

# %%
import sys
# !{sys.executable} -m pip install "numpy==1.26.4" --force-reinstall
# !{sys.executable} -m pip install spacy==3.4.4 --force-reinstall
# Out:
# ...
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/15.8 MB 3.4 MB/s eta 0:00:05
#    --- ------------------------------------ 1.6/15.8 MB 4.4 MB/s eta 0:00:04
#    ------- -------------------------------- 2.9/15.8 MB 5.2 MB/s eta 0:00:03
#    --------- ------------------------------ 3.9/15.8 MB 5.2 MB/s eta 0:00:03
#    ------------- -------------------------- 5.2/15.8 MB 5.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 7.1/15.8 MB 6.1 MB/s eta 0:00:02
#    ------------------------ --------------- 9.7/15.8 MB 7.0 MB/s eta 0:00:01
#    -------------------------------- ------- 12.8/15.8 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.8 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 8.6 MB/s  0:00:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.4
#     Uninstalling numpy-2.4.4:
# ...

# %%
import sys
print(f"Python: {sys.version}")

import numpy as np
print(f"NumPy: {np.__version__}")

import spacy
print(f"spaCy: {spacy.__version__}")

nlp = spacy.load("en_core_sci_md")
print("SciSpaCy loaded successfully!")
# Out:
# Python: 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# NumPy: 2.4.4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 7
#       3
#       4 import numpy as np
#       5 print(f"NumPy: {np.__version__}")
#       6
# ----> 7 import spacy
#       8 print(f"spaCy: {spacy.__version__}")
#       9
#      10 nlp = spacy.load("en_core_sci_md")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\spacy\__init__.py:6
#       3 import sys
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\spacy\errors.py:2
#       1 import warnings
# ----> 2 from .compat import Literal
# ...

# %%
import sys
# !{sys.executable} -m pip install "numpy==1.24.3" --force-reinstall --no-deps
